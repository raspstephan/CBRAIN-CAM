# %% [markdown]
# # Analysis and Figures for GRL paper
#
# This notebook contains all analysis and figures for the GRL paper. Most of the heavy lifting is done by the ModelDiagnostics class. So please check it out for more details.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from cbrain.imports import *
from cbrain.model_diagnostics import *
from cbrain.utils import *
import matplotlib as mpl
from matplotlib import patches, patheffects
from matplotlib.animation import FuncAnimation
from IPython.display import SVG, HTML
from string import ascii_lowercase
# %matplotlib inline
limit_mem()
# Out:
# /export/home/gyacalis/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
MODEL_DIR = '/export/home/srasp/repositories/CBRAIN-CAM/saved_models/'
DATA_DIR = '/scratch/srasp/preprocessed_data/'

# %%
def get_d(m, trn='sample1', val='sample1', eps=''):
    d = ModelDiagnostics(
        MODEL_DIR+f'{m}.h5',
        fpath=f'{DATA_DIR}paper_nonorm_valid_{val}_features.nc',
        tpath=f'{DATA_DIR}paper_nonorm_valid_{val}_targets.nc',
        npath=f'{DATA_DIR}paper_nonorm_train_{trn}_norm.nc',
        norms=('feature_means', 'feature_stds'+eps, None, 'target_conv')
    )
    return d

# %% [markdown]
# ## Network architecture sensitivity test
#
# - Training: 60 days. Days 5-9 from each month of year 1.
# - Validation: 60 days. Days 5-9 from each month of year 2.
#
# The goal of this sensitivity test is to assess the number of parameters and the arrangement (shallow vs. wide).
#
# - Number of input variables: 123
# - Number of output variables: 120
#
# All networks are trained with LeakyReLU activation functions $z(a) = \max(0.3x, x)$.
#
# The loss function is the mean squared error.
#
# These networks were trained with a batch size of 1024 (see sensitivity below). The starting learning rate was 1e-3. Every 5 epochs the learning rate was divided by 5. We trained for 20 epochs.
#
# For input normalization, we are subtracting each variable by its mean and then divide it by its standard deviation to get mean zero, standard deviation one.
#
# For the outputs we are multiplying the heating tendencies (TPHYSTND_NORAD, QRL, QRS) by $C_p = 1 \times 10^3$ and the moistening tendency PHQ by $L_v = 2.5 \times 10^6$, so that they are all in energy units W/m^2.

# %%
def npar(l):
    l = [l] if not type(l) == list else l
    l = [123] + l + [120]
    return sum([l[i] * l[i+1] + l[i+1] for i in range(len(l)-1)])

# %%
l_shallow = [128, 512, 2048, 8192]
l_medium = [[l]*2 for l in [90, 256, 600, 1300]]
l_deep = [[l]*8 for l in [50, 115, 256, 512]]

# %% [markdown]
# **Architectures**
#
# | Approx. # Param | 30k | 125k | 500k | 2M |
# | --- | --- | --- | --- | --- |
# | Shallow | 128 | 512 | 2048 | 8192 |
# | Medium | 90 x 2 | 256 x 2 | 600 x 2 | 1300 x 2 |
# | Deep | 50 x 8 | 115 x 8 | 256 x 8 | 512 x 8 |
#
# *Note that powers of 2 are usually chosen for GPU speed. For the sensitivity test we disregarded this sometimes.*

# %%
mlist_shallow = ['P001_128_sample1', 'P002_512_sample1', 'P003_2048_sample1', 'P004_8192_sample1']
mlist_medium = ['P005_90x2_sample1', 'P006_256x2_sample1', 'P007_600x2_sample1', 'P008_1300x2_sample1']
mlist_deep = ['P009_50x8_sample1', 'P010_115x8_sample1', 'P011_256x8_sample1', 'P012_512x8_sample1']

# %%
npars_shallow = [npar(l) for l in l_shallow]
npars_medium = [npar(l) for l in l_medium]
npars_deep = [npar(l) for l in l_deep]

# %%
plt.scatter(range(4), npars_shallow, marker='o')
plt.scatter(range(4), npars_medium, marker='o')
plt.scatter(range(4), npars_deep, marker='o')
plt.gca().set_yscale('log')

# %%
dlist = list()
for mlist in [mlist_shallow, mlist_medium, mlist_deep]:
    tmp = []
    for m in mlist:
        d = get_d(m)
        if os.path.exists('./tmp/' + d.save_str): d.load_stats()
        else: d.compute_stats(); d.save_stats()
        tmp.append(d)
    dlist.append(tmp)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-1fc92282ff5a> in <module>()
#       3     tmp = []
#       4     for m in mlist:
# ----> 5         d = get_d(m)
#       6         if os.path.exists('./tmp/' + d.save_str): d.load_stats()
#       7         else: d.compute_stats(); d.save_stats()
#
# <ipython-input-4-7884e3ebfda6> in get_d(m, trn, val, eps)
#       5         tpath=f'{DATA_DIR}paper_nonorm_valid_{val}_targets.nc',
#       6         npath=f'{DATA_DIR}paper_nonorm_train_{trn}_norm.nc',
# ----> 7         norms=('feature_means', 'feature_stds'+eps, None, 'target_conv')
#       8     )
#       9     return d
#
# /data11/home/srasp/repositories/CBRAIN-CAM/notebooks/presentation/cbrain/model_diagnostics.py in __init__(self, model_path, is_tf, fpath, tpath, npath, norms, tf_filepattern, tf_fvars, tf_tvars, tf_meanpath, tf_stdpath, nlat, nlon, nlev, ntime, raw_nlev, watch_mem, convo, convo_tile)
#      57         # Get variable names and open arrays
#      58         if self.is_k:
# ---> 59             self.k_norm = h5py.File(npath, 'r')
#      60             self.target_size = self.k_norm['target_names'][:].shape[0]
#      61             self._get_k_norm_arrs(*norms)
#
# ~/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     267             with phil:
#     268                 fapl = make_fapl(driver, libver, **kwds)
# --> 269                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     270
#     271                 if swmr_support:
#
# ~/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#      97         if swmr and swmr_support:
#      98             flags |= h5f.ACC_SWMR_READ
# ---> 99         fid = h5f.open(name, flags, fapl=fapl)
#     100     elif mode == 'r+':
#     101         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = '/scratch/srasp/preprocessed_data/paper_nonorm_train_sample1_norm.nc', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
r2s = [[d.mean_stats(10)['hor_r2']['all'] for d in dd] for dd in dlist]

# %%
plt.scatter(npars_shallow, r2s[0], marker='o', label='shallow')
plt.scatter(npars_medium, r2s[1], marker='o', label='medium')
plt.scatter(npars_deep, r2s[2], marker='o', label='deep')
plt.gca().set_xscale('log'); plt.legend();
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-d363058e87b3> in <module>()
# ----> 1 plt.scatter(npars_shallow, r2s[0], marker='o', label='shallow')
#       2 plt.scatter(npars_medium, r2s[1], marker='o', label='medium')
#       3 plt.scatter(npars_deep, r2s[2], marker='o', label='deep')
#       4 plt.gca().set_xscale('log'); plt.legend();
#
# IndexError: list index out of range

# %%
factors = np.array([C_P, L_V, C_P, C_P]); factors
# Out:
# array([1.00464e+03, 2.50100e+06, 1.00464e+03, 1.00464e+03])

# %%
mses = [
    [(d.mean_stats()['mse'][:4].values.astype('float') * factors**2).mean() for d in dd] 
    for dd in dlist]

# %%
def plot_arch_sens(ax, s=50):
    ax.scatter(npars_shallow, mses[0], marker='o', label='shallow',s=s)
    ax.scatter(npars_medium, mses[1], marker='x', label='medium',s=s)
    ax.scatter(npars_deep, mses[2], marker='^', label='deep',s=s)
    ax.set_xscale('log'); ax.legend();
    ax.set_ylim(np.min(mses)*0.98, np.max(mses)*1.02); ax.set_xlim(2e4, 3e6);
    ax.set_xlabel('Number of network parameters')
    ax.set_ylabel(r'MSE [W$^2$/m$^4$]')
    ax.set_title('a) Sensitivity to network architecture')
    ax.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
    despine(ax)

# %%
fig, ax = plt.subplots(figsize=(4.5, 3))
plot_arch_sens(ax)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-477198c7fe94> in <module>()
#       1 fig, ax = plt.subplots(figsize=(4.5, 3))
# ----> 2 plot_arch_sens(ax)
#
# <ipython-input-15-4ee13c2799ee> in plot_arch_sens(ax, s)
#       1 def plot_arch_sens(ax, s=50):
# ----> 2     ax.scatter(npars_shallow, mses[0], marker='o', label='shallow',s=s)
#       3     ax.scatter(npars_medium, mses[1], marker='x', label='medium',s=s)
#       4     ax.scatter(npars_deep, mses[2], marker='^', label='deep',s=s)
#       5     ax.set_xscale('log'); ax.legend();
#
# IndexError: list index out of range

# %% [markdown]
# ### Does it matter whether we validate with 60 days or a full year?

# %%
d_fullyear = get_d(mlist[1], val='fullyear')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-9cf739c94792> in <module>()
# ----> 1 d_fullyear = get_d(mlist[1], val='fullyear')
#
# <ipython-input-4-7884e3ebfda6> in get_d(m, trn, val, eps)
#       5         tpath=f'{DATA_DIR}paper_nonorm_valid_{val}_targets.nc',
#       6         npath=f'{DATA_DIR}paper_nonorm_train_{trn}_norm.nc',
# ----> 7         norms=('feature_means', 'feature_stds'+eps, None, 'target_conv')
#       8     )
#       9     return d
#
# /data11/home/srasp/repositories/CBRAIN-CAM/notebooks/presentation/cbrain/model_diagnostics.py in __init__(self, model_path, is_tf, fpath, tpath, npath, norms, tf_filepattern, tf_fvars, tf_tvars, tf_meanpath, tf_stdpath, nlat, nlon, nlev, ntime, raw_nlev, watch_mem, convo, convo_tile)
#      57         # Get variable names and open arrays
#      58         if self.is_k:
# ---> 59             self.k_norm = h5py.File(npath, 'r')
#      60             self.target_size = self.k_norm['target_names'][:].shape[0]
#      61             self._get_k_norm_arrs(*norms)
#
# ~/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     267             with phil:
#     268                 fapl = make_fapl(driver, libver, **kwds)
# --> 269                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     270
#     271                 if swmr_support:
#
# ~/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#      97         if swmr and swmr_support:
#      98             flags |= h5f.ACC_SWMR_READ
# ---> 99         fid = h5f.open(name, flags, fapl=fapl)
#     100     elif mode == 'r+':
#     101         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = '/scratch/srasp/preprocessed_data/paper_nonorm_train_sample1_norm.nc', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
d_fullyear.compute_stats(); d_fullyear.save_stats()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-56adcbcdc23b> in <module>()
# ----> 1 d_fullyear.compute_stats(); d_fullyear.save_stats()
#
# NameError: name 'd_fullyear' is not defined

# %%
d_fullyear.load_stats()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-e2b2935ee920> in <module>()
# ----> 1 d_fullyear.load_stats()
#
# NameError: name 'd_fullyear' is not defined

# %%
d_fullyear.mean_stats(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-da5ef17f91bd> in <module>()
# ----> 1 d_fullyear.mean_stats(10)
#
# NameError: name 'd_fullyear' is not defined

# %%
dlist[1].mean_stats(10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-f8a06c914ae2> in <module>()
# ----> 1 dlist[1].mean_stats(10)
#
# IndexError: list index out of range

# %% [markdown]
# There is harldy any difference between the statistics computed for 60 days and for a full year. To speed up analysis we will use the 60 day version.

# %% [markdown]
# ### Batch size sensitivity
#
# ATTENTION! This is not up-to-date. The experiments below suffered from a bug and therefore do not represent the actual sensitivity.

# %%
bss = [128, 256, 512, 1024]

# %%
bs_list = ['P015_512x8_sample1_bs128', 'P014_512x8_sample1_bs256', 'P013_512x8_sample1_bs512',
           'P012_512x8_sample1']

# %%
bsd = []
for b in bs_list:
    d = get_d(b)
    if os.path.exists('./tmp/' + d.save_str): d.load_stats()
    else: d.compute_stats(); d.save_stats()
    bsd.append(d)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-25-e6ee7ee467e2> in <module>()
#       1 bsd = []
#       2 for b in bs_list:
# ----> 3     d = get_d(b)
#       4     if os.path.exists('./tmp/' + d.save_str): d.load_stats()
#       5     else: d.compute_stats(); d.save_stats()
#
# <ipython-input-4-7884e3ebfda6> in get_d(m, trn, val, eps)
#       5         tpath=f'{DATA_DIR}paper_nonorm_valid_{val}_targets.nc',
#       6         npath=f'{DATA_DIR}paper_nonorm_train_{trn}_norm.nc',
# ----> 7         norms=('feature_means', 'feature_stds'+eps, None, 'target_conv')
#       8     )
#       9     return d
#
# /data11/home/srasp/repositories/CBRAIN-CAM/notebooks/presentation/cbrain/model_diagnostics.py in __init__(self, model_path, is_tf, fpath, tpath, npath, norms, tf_filepattern, tf_fvars, tf_tvars, tf_meanpath, tf_stdpath, nlat, nlon, nlev, ntime, raw_nlev, watch_mem, convo, convo_tile)
#      57         # Get variable names and open arrays
#      58         if self.is_k:
# ---> 59             self.k_norm = h5py.File(npath, 'r')
#      60             self.target_size = self.k_norm['target_names'][:].shape[0]
#      61             self._get_k_norm_arrs(*norms)
#
# ~/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     267             with phil:
#     268                 fapl = make_fapl(driver, libver, **kwds)
# --> 269                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     270
#     271                 if swmr_support:
#
# ~/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#      97         if swmr and swmr_support:
#      98             flags |= h5f.ACC_SWMR_READ
# ---> 99         fid = h5f.open(name, flags, fapl=fapl)
#     100     elif mode == 'r+':
#     101         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = '/scratch/srasp/preprocessed_data/paper_nonorm_train_sample1_norm.nc', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
plt.plot(bss, [d.mean_stats(10)['hor_r2']['all'] for d in bsd]);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-5611b1360303> in <module>()
# ----> 1 plt.plot(bss, [d.mean_stats(10)['hor_r2']['all'] for d in bsd]);
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1525         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1526
# -> 1527         for line in self._get_lines(*args, **kwargs):
#    1528             self.add_line(line)
#    1529             lines.append(line)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     381             x, y = index_of(tup[-1])
#     382
# --> 383         x, y = self._xy_from_xy(x, y)
#     384
#     385         if self.command == 'plot':
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     240         if x.shape[0] != y.shape[0]:
#     241             raise ValueError("x and y must have same first dimension, but "
# --> 242                              "have shapes {} and {}".format(x.shape, y.shape))
#     243         if x.ndim > 2 or y.ndim > 2:
#     244             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (4,) and (0,)

# %%
plt.plot(bss, [(d.mean_stats()['mse'][:4].values.astype('float') * factors**2).mean() for d in bsd] );
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-da8b1addf8b6> in <module>()
# ----> 1 plt.plot(bss, [(d.mean_stats()['mse'][:4].values.astype('float') * factors**2).mean() for d in bsd] );
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1525         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1526
# -> 1527         for line in self._get_lines(*args, **kwargs):
#    1528             self.add_line(line)
#    1529             lines.append(line)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     381             x, y = index_of(tup[-1])
#     382
# --> 383         x, y = self._xy_from_xy(x, y)
#     384
#     385         if self.command == 'plot':
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     240         if x.shape[0] != y.shape[0]:
#     241             raise ValueError("x and y must have same first dimension, but "
# --> 242                              "have shapes {} and {}".format(x.shape, y.shape))
#     243         if x.ndim > 2 or y.ndim > 2:
#     244             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (4,) and (0,)

# %% [markdown]
# The results here are a little unintuitive. Part of it could be random scatter, but given our amount of data that seems unlikely. More likely is a non-optimal tuning of the learning rate schedule with batch size. In fact a look at the TensorBoard graph suggests exactly that. At larger learning rates the loos shoots off to very large values.
#
# However, the difference between the batch sizes is much smaller than the difference between diferent architectures, which is why we will keep using bs=1024 noting that large batch sizes speed up training.

# %% [markdown]
# ## Training amount sensitivity tests
#
# Using the large, deep network.
#
# - Training with continuous periods:
#     - 1 week
#     - 1 month
#     - 3 month
#     - 6 month
#     - 9 month
#     - 12 month

# %%
tds = []
for i, t in enumerate(['P016_512x8_10days', 'P017_512x8_30days','P018_512x8_90days', 
                       'P019_512x8_180days', 'P020_512x8_270days', 'P021_512x8_fullyear']):
    # This is an ugly hack.
    # For the larger networks I saw weird behavior during training sometimes...
    # So I set a lower bound (eps=1e-10) to divide the input features by.
    # This does not affect performance, so we should be good!
    d = get_d(t, eps='' if i<3 else '_eps')
    if os.path.exists('./tmp/' + d.save_str): d.load_stats()
    else: d.compute_stats(); d.save_stats()
    tds.append(d)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-28-c5b2147a3bf0> in <module>()
#       6     # So I set a lower bound (eps=1e-10) to divide the input features by.
#       7     # This does not affect performance, so we should be good!
# ----> 8     d = get_d(t, eps='' if i<3 else '_eps')
#       9     if os.path.exists('./tmp/' + d.save_str): d.load_stats()
#      10     else: d.compute_stats(); d.save_stats()
#
# <ipython-input-4-7884e3ebfda6> in get_d(m, trn, val, eps)
#       5         tpath=f'{DATA_DIR}paper_nonorm_valid_{val}_targets.nc',
#       6         npath=f'{DATA_DIR}paper_nonorm_train_{trn}_norm.nc',
# ----> 7         norms=('feature_means', 'feature_stds'+eps, None, 'target_conv')
#       8     )
#       9     return d
#
# /data11/home/srasp/repositories/CBRAIN-CAM/notebooks/presentation/cbrain/model_diagnostics.py in __init__(self, model_path, is_tf, fpath, tpath, npath, norms, tf_filepattern, tf_fvars, tf_tvars, tf_meanpath, tf_stdpath, nlat, nlon, nlev, ntime, raw_nlev, watch_mem, convo, convo_tile)
#      57         # Get variable names and open arrays
#      58         if self.is_k:
# ---> 59             self.k_norm = h5py.File(npath, 'r')
#      60             self.target_size = self.k_norm['target_names'][:].shape[0]
#      61             self._get_k_norm_arrs(*norms)
#
# ~/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     267             with phil:
#     268                 fapl = make_fapl(driver, libver, **kwds)
# --> 269                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     270
#     271                 if swmr_support:
#
# ~/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#      97         if swmr and swmr_support:
#      98             flags |= h5f.ACC_SWMR_READ
# ---> 99         fid = h5f.open(name, flags, fapl=fapl)
#     100     elif mode == 'r+':
#     101         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = '/scratch/srasp/preprocessed_data/paper_nonorm_train_sample1_norm.nc', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
def plot_time_sens(ax, s=50):
    days = np.array([10, 30, 90, 180, 270, 365])
    months = days/365*12
    score = [(d.mean_stats()['mse'][:4].values.astype('float') * factors**2).mean() for d in tds];
    #score = [d.mean_stats(10)['hor_r2']['all'] for d in tds]
    ax.scatter(months, score, marker='^', s=s, c='C2')
    ax.set_ylim(np.min(score)*0.95, np.max(score)*1.05); 
    ax.set_xlim(0, 12.5);
    ax.set_xlabel('Months of training data')
    ax.set_ylabel(r'MSE [W$^2$/m$^4$]')
    ax.set_title('b) Sensitivity to amount of training data')
    ax.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
    despine(ax)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 3.5))
plot_arch_sens(axes[0], 60)
plot_time_sens(axes[1], 60)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-e3ed790832f9> in <module>()
#       1 fig, axes = plt.subplots(1, 2, figsize=(12, 3.5))
# ----> 2 plot_arch_sens(axes[0], 60)
#       3 plot_time_sens(axes[1], 60)
#
# <ipython-input-15-4ee13c2799ee> in plot_arch_sens(ax, s)
#       1 def plot_arch_sens(ax, s=50):
# ----> 2     ax.scatter(npars_shallow, mses[0], marker='o', label='shallow',s=s)
#       3     ax.scatter(npars_medium, mses[1], marker='x', label='medium',s=s)
#       4     ax.scatter(npars_deep, mses[2], marker='^', label='deep',s=s)
#       5     ax.set_xscale('log'); ax.legend();
#
# IndexError: list index out of range

# %% [markdown]
# ## Geographical figures

# %% [markdown]
# ### Setup

# %%
# Load model for figures
d = get_d('P021_512x8_fullyear', val='sample1', eps='_eps')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-38-7c7f923e8409> in <module>()
#       1 # Load model for figures
# ----> 2 d = get_d('P021_512x8_fullyear', val='sample1', eps='_eps')
#
# <ipython-input-4-7884e3ebfda6> in get_d(m, trn, val, eps)
#       5         tpath=f'{DATA_DIR}paper_nonorm_valid_{val}_targets.nc',
#       6         npath=f'{DATA_DIR}paper_nonorm_train_{trn}_norm.nc',
# ----> 7         norms=('feature_means', 'feature_stds'+eps, None, 'target_conv')
#       8     )
#       9     return d
#
# /data11/home/srasp/repositories/CBRAIN-CAM/notebooks/presentation/cbrain/model_diagnostics.py in __init__(self, model_path, is_tf, fpath, tpath, npath, norms, tf_filepattern, tf_fvars, tf_tvars, tf_meanpath, tf_stdpath, nlat, nlon, nlev, ntime, raw_nlev, watch_mem, convo, convo_tile)
#      57         # Get variable names and open arrays
#      58         if self.is_k:
# ---> 59             self.k_norm = h5py.File(npath, 'r')
#      60             self.target_size = self.k_norm['target_names'][:].shape[0]
#      61             self._get_k_norm_arrs(*norms)
#
# ~/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     267             with phil:
#     268                 fapl = make_fapl(driver, libver, **kwds)
# --> 269                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     270
#     271                 if swmr_support:
#
# ~/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#      97         if swmr and swmr_support:
#      98             flags |= h5f.ACC_SWMR_READ
# ---> 99         fid = h5f.open(name, flags, fapl=fapl)
#     100     elif mode == 'r+':
#     101         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = '/scratch/srasp/preprocessed_data/paper_nonorm_train_sample1_norm.nc', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
d.load_stats()

# %%
# Load one xarray file to get coordinates
ds = xr.open_dataset('/scratch/srasp/Aquaplanet_enhance05/AndKua_aqua_SPCAM3.0_enhance05.cam2.h1.0000-01-01-00000.nc',
                     decode_times=False)

# %%
lat, lon, lev = ds.lat.values, ds.lon.values, ds.lev.values

# %%
# Make sure lat-lon and lev-lat plots have same sizes
# Width / height
latrange = lat.max()-lat.min(); lonrange = lon.max()-lon.min(); levrange = lev.max()-lev.min()
tmp = lonrange / latrange
asp = (latrange/tmp)/levrange; asp
# Out:
# 0.0874230126630051

# %%
vars = ['TPHYSTND_NORAD', 'PHQ', 'QRL', 'QRS']

# %%
# Full names
name = {
    'TPHYSTND_NORAD': 'Convective heating rate',
    'PHQ': 'Convective moistening rate',
    'QRL': 'Longwave heating rate',
    'QRS': 'Shortwave heating rate'
}

# %%
# Units
unit = {
    'TPHYSTND_NORAD': '[K/s]',
    'PHQ': '[kg/kg/s]',
    'QRL': '[K/s]',
    'QRS': '[K/s]'
}

# %%
def plot_panels(axes, p, t, var, cmap='bwr', xlabel=True, title='var', labels=None,
                yz=False):
    if yz:
        x, y = lat, lev
        p, t = p.T, t.T
    else: 
        x, y = lon, lat
    I1, I2 = [ax.pcolormesh(x, y, a, vmin=lims[var][0], vmax=lims[var][1], cmap=cmap) 
              for ax, a in zip(axes.flat, [p, t])]
    if not yz: [ax.set_aspect('equal') for ax in axes.flat]
    if yz: [ax.invert_yaxis() for ax in axes.flat]
    if xlabel: 
        [ax.set_xlabel('Latitude' if yz else 'Longitude') for ax in axes.flat]
        if not yz: [ax.set_xticks(range(0, 361, 60)) for ax in axes.flat]
    else: [ax.set_xticks([]) for ax in axes.flat]
    axes[0].set_ylabel('Pressure [hPa]' if yz else 'Latitude'); axes[1].set_yticks([])
    if title == 'var':
        pos = [ax.get_position().get_points() for ax in axes.flat]
        pos = pos[0][1][1]
        plt.text(0.45, pos-0.01, name[var], transform=plt.gcf().transFigure,
                 horizontalalignment='center', fontsize=12)
    else:
        axes[0].set_title('CBRAIN Predictions'); axes[1].set_title('SP-CAM Truth')
    if labels is not None:
        [ax.text(0.01, 0.90, l, transform=ax.transAxes, fontsize=12)
         for ax, l in zip(axes, labels)]
    cb = fig.colorbar(I1, ax=axes.ravel().tolist(), shrink=0.75, pad=0.01, extend='both')
    cb.set_label(unit[var])
    cb.formatter.set_powerlimits((-1, 1))
    cb.ax.yaxis.set_offset_position('left') 
    cb.update_ticks()
    return I1, I2

# %%
def xy_wrap(axes, itime, ilev, var, **kwargs):
    p, t = d.get_pt(itime=itime, var=var)
    return plot_panels(axes, p[:, :, ilev], t[:, :, ilev], var, **kwargs)

# %%
def yz_wrap(axes, itime, ilon, var, **kwargs):
    p, t = d.get_pt(itime=itime, var=var)
    return plot_panels(axes, p[:, ilon, :], t[:, ilon, :], var, **kwargs)

# %%
def animate_lat_lon(ilev, var, max_time=5, interval=200):
    p, t = d.get_pt(itime=0, var=var)
    fig, axes = plt.subplots(1, 2, figsize=(15, 4))
    plt.subplots_adjust(wspace=0.03)
    I1, I2 = plot_panels(axes, p[:, :, ilev], t[:, :, ilev], var, title='other')
    fig.suptitle('Time = 0')
    def update(i):
        p, t = d.get_pt(itime=i, var=var)
        fig.suptitle(f'Time = {i}')
        I1.set_array(p[:, :, ilev].ravel()); I2.set_array(t[:, :, ilev].ravel())
        return I1, I2, 
    plt.close(fig)
    return FuncAnimation(fig, update, frames=np.arange(1, max_time), interval=interval, blit=True)

# %%
def despine(ax):
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

# %% [markdown]
# ### Lat-lon snapshots

# %%
labels = []
for i in range(4):
    labels.append([f'{ascii_lowercase[i*2]}) CBRAIN', f'{ascii_lowercase[i*2+1]}) SP-CAM'])

# %%
lev[20]
# Out:
# 691.3894303143024

# %%
# Plotting ranges
lims = {
    'TPHYSTND_NORAD': [-5e-4, 5e-4],
    'PHQ': [-2e-7, 2e-7],
    'QRL': [-1e-4, 1e-4],
    'QRS': [-1e-4, 1e-4],
}

# %%
fig, axes = plt.subplots(4, 2, figsize=(15, 15))
plt.subplots_adjust(wspace=0.03, hspace=0.)
for i, v in enumerate(vars): 
    xy_wrap(axes[i], 0, 20, v, xlabel = True if i == 3 else False, labels=labels[i], cmap='RdBu_r')

# %%
figdir = './figures/'
os.makedirs(figdir, exist_ok=True)

# %%
fig.savefig(f'{figdir}lat-lon-snap.pdf', bbox_inches='tight', dpi=200)

# %% [markdown]
# #### Animation

# %%
d = get_d('P021_512x8_fullyear', val='fullyear', eps='_eps')

# %%
d.compute_stats()
# Out:
# 100%|██████████| 17519/17519 [21:36<00:00, 13.51it/s]
# /data11/home/srasp/repositories/CBRAIN-CAM/notebooks/presentation/cbrain/model_diagnostics.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   self.stats['r2'] = 1. - (self.stats['mse'] / self.stats['true_var'])
# /data11/home/srasp/repositories/CBRAIN-CAM/notebooks/presentation/cbrain/model_diagnostics.py:243: RuntimeWarning: invalid value encountered in true_divide
#   self.stats['r2'] = 1. - (self.stats['mse'] / self.stats['true_var'])
# /data11/home/srasp/repositories/CBRAIN-CAM/notebooks/presentation/cbrain/model_diagnostics.py:249: RuntimeWarning: invalid value encountered in true_divide
#   self.stats['hor_r2'] = 1 - (self.stats['hor_mse'] / self.stats['hor_tvar'])

# %%
lims = {
    'TPHYSTND_NORAD': [-6e-4, 6e-4],
    'PHQ': [-4e-7, 4e-7],
    'QRL': [-1.5e-4, 1.5e-4],
    'QRS': [-1.5e-4, 1.5e-4],
}

# %%
def make_animation(max_time, interval=200, ilev=20, ilon=0, yz=False):
    """Bit of a hacky animation function, but I could not figure out how set_array works for pcolormesh."""
    if yz:
        il = ilon
        x, y = lat, lev
        func = yz_wrap
        fig, axes = plt.subplots(4, 2, figsize=(12, 13))
        plt.subplots_adjust(wspace=0.03, hspace=0.00, left=0.05, right=1.05, top=0.95, bottom=0.05)
    else: 
        il = ilev
        x, y = lon, lat
        func = xy_wrap
        fig, axes = plt.subplots(4, 2, figsize=(12, 13))
        plt.subplots_adjust(wspace=0.03, hspace=0.00, left=0.05, right=1.05, top=0.95, bottom=0.05)
    I_list = []
    for i, v in enumerate(vars): 
        I_list.extend(
            func(axes[i], 0, il, v, xlabel = True if i == 3 else False, labels=labels[i], cmap='RdBu_r', yz=yz))
    if yz: [ax.set_aspect(asp) for ax in axes.flat]
    def update(i):
        tstr = '%.1f hours'%(i*0.5)
        fig.suptitle(f'Time = {tstr}', x=0.47, y=0.98)
        for iv, v in enumerate(vars): 
            p, t = d.get_pt(itime=i, var=v)
            if yz: p, t = p[:, il].T, t[:, il].T
            else: p, t = p[:, :, il], t[:, :, il]
            tmp = [ax.pcolormesh(x, y, a, vmin=lims[v][0], vmax=lims[v][1], cmap='RdBu_r') 
                      for ax, a in zip(axes[iv], [p, t])]
        return tuple(I_list)
    plt.close(fig)
    return FuncAnimation(fig, update, frames=np.arange(1, max_time), interval=interval, blit=True)

# %%
anim = make_animation(48*3, interval=120)

# %%
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-262-f885f4acf935> in <module>()
# ----> 1 HTML(anim.to_html5_video())
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1351                                 bitrate=rcParams['animation.bitrate'],
#    1352                                 fps=1000. / self._interval)
# -> 1353                 self.save(f.name, writer=writer)
#    1354
#    1355             # Now open and base64 encode
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1198                         # TODO: See if turning off blit is really necessary
#    1199                         anim._draw_next_frame(d, blit=False)
# -> 1200                     writer.grab_frame(**savefig_kwargs)
#    1201
#    1202         # Reconnect signal for first draw if necessary
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py in grab_frame(self, **savefig_kwargs)
#     383             # frame format and dpi.
#     384             self.fig.savefig(self._frame_sink(), format=self.frame_format,
# --> 385                              dpi=self.dpi, **savefig_kwargs)
#     386         except (RuntimeError, IOError) as e:
#     387             out, err = self._proc.communicate()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_raw(self, filename_or_obj, *args, **kwargs)
#     492
#     493     def print_raw(self, filename_or_obj, *args, **kwargs):
# --> 494         FigureCanvasAgg.draw(self)
#     495         renderer = self.get_renderer()
#     496         original_dpi = renderer.dpi
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     431             # if toolbar:
#     432             #     toolbar.set_cursor(cursors.WAIT)
# --> 433             self.figure.draw(self.renderer)
#     434             # A GUI class may be need to update a window using this draw, so
#     435             # don't forget to call the superclass.
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1473
#    1474             mimage._draw_list_compositing_images(
# -> 1475                 renderer, self, artists, self.suppressComposite)
#    1476
#    1477             renderer.close_group('figure')
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2605             renderer.stop_rasterizing()
#    2606
# -> 2607         mimage._draw_list_compositing_images(renderer, self, artists)
#    2608
#    2609         renderer.close_group('axes')
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/collections.py in draw(self, renderer)
#    1980                 gc, transform.frozen(), self._meshWidth, self._meshHeight,
#    1981                 coordinates, offsets, transOffset, self.get_facecolor(),
# -> 1982                 self._antialiased, self.get_edgecolors())
#    1983         gc.restore()
#    1984         renderer.close_group(self.__class__.__name__)
#
# KeyboardInterrupt:

# %%
anim.save(f'{figdir}lat-lon-animation.mp4')

# %% [markdown]
# ### Lev-Lat snapshots

# %%
lon[64]
# Out:
# 180.0

# %%
# Change plotting ranges for clearer figures
lims = {
    'TPHYSTND_NORAD': [-4e-4, 4e-4],
    'PHQ': [-4e-7, 4e-7],
    'QRL': [-1.5e-4, 1.5e-4],
    'QRS': [-1.5e-4, 1.5e-4],
}

# %%
fig, axes = plt.subplots(4, 2, figsize=(15, 15))
plt.subplots_adjust(wspace=0.03, hspace=0.)
for i, v in enumerate(vars): 
    yz_wrap(axes[i], 0, 64, v, xlabel = True if i == 3 else False, labels=labels[i], yz=True,
            cmap='RdBu_r')
[ax.set_aspect(asp) for ax in axes.flat];

# %%
fig.savefig(f'{figdir}height-lat-snap.pdf', bbox_inches='tight', dpi=200)

# %% [markdown]
# #### Animation

# %%
anim = make_animation(48*3, interval=120, yz=True)

# %%
HTML(anim.to_html5_video())

# %%
anim.save(f'{figdir}height-lat-animation.mp4')

# %% [markdown]
# ### Statistics
#
# lat-lev, averaged over lon: MSE, TVAR, PVAR, R2, bias
#
# lev, averaged over lat, lon: R2
#
# For each output variable [TPHYSTND_NORAD, PHQ, QRL, QRS] the $R^2$ is computed for each level $z$ and then averaged:
#
# $$ R^2_z = 1 - (SSE_z / TVAR_z) $$
#
# where SSE, the sum of squared errors is computed from the predicted values $y$ and the corresponding true values $\hat{y}$:
#
# $$ SSE_z = \frac{1}{nt \times nx \times ny}\sum_{nt}\sum_{nx}\sum_{ny} (y_{t, x, y} - \hat{y}_{t, x, y})^2$$
#
# and the TVAR, the true variance is:
#
# $$ TVAR_Z = \frac{1}{nt \times nx \times ny}\sum_{nt}\sum_{nx}\sum_{ny} (\hat{y}_{t, x, y} - \bar{\hat{y}})^2 $$
#
# with $\bar{\hat{y}}$ being the true mean over $t, x, y$.

# %% [markdown]
# #### Setup

# %%
d.stats.keys()
# Out:
# dict_keys(['bias', 'mse', 'pred_mean', 'true_mean', 'pred_sqmean', 'true_sqmean', 'pred_var', 'true_var', 'r2', 'hor_tsqmean', 'hor_tmean', 'hor_mse', 'hor_tvar', 'hor_r2'])

# %%
labels2 = []
for i in range(4):
    labels2.append([f'{ascii_lowercase[i*2]}) Bias', f'{ascii_lowercase[i*2+1]}) RMSE'])

# %%
def draw_outline(o, lw):
    o.set_path_effects([patheffects.Stroke(
        linewidth=lw, foreground='white'), patheffects.Normal()])

# %%
def plot_4stats(d, stat, title='', vmult=1, only_pos=False, func=None, mylims=None, rows=2,
                letter_offset=0, masks=None, extend='both', **kwargs):
    fig, axes = plt.subplots(rows, 2, figsize=(15, 3.5 * rows))
    axes = np.atleast_2d(axes)
    plt.subplots_adjust(wspace=0.0, hspace=0.)
    for i, (ax, v) in enumerate(zip(axes.flat, vars)):
        if func:
            a = func(d, v)
        else:
            a = d.stats[stat][:,:,d.tvars.index(v)].mean(1)
        if mylims is None: 
            vmin = 0 if only_pos else lims[v][0]*vmult
            vmax = lims[v][1]*vmult
        else:
            vmin = mylims[0]; vmax = mylims[1]
        if masks is not None: a[masks[i]] = np.nan
        I = ax.pcolormesh(lat, lev, a.T, vmin=vmin, vmax=vmax, **kwargs)
        txt = ax.text(0.01, 0.90, f'{ascii_lowercase[i+letter_offset]}) {name[v]}', 
                      transform=ax.transAxes, fontsize=12)
        draw_outline(txt, 2)
        cb = fig.colorbar(I, ax=ax, orientation='vertical', shrink=0.8, pad=0.02, 
                          extend=extend)
        cb.set_label(unit[v])
        cb.formatter.set_powerlimits((-1, 1))
        cb.ax.yaxis.set_offset_position('left') 
        cb.update_ticks()
        
    [ax.set_ylabel('Pressure [hPa]') for ax in axes[:,0].flat]
    [ax.set_yticks([]) for ax in axes[:,1].flat]
    [ax.invert_yaxis() for ax in axes.flat]
    if rows > 1: [ax.set_xticks([]) for ax in axes[0].flat]
    [ax.set_xlabel('Latitude') for ax in axes[-1].flat]
    [ax.set_aspect(asp) for ax in axes.flat];
    fig.suptitle(title, fontsize=14, x=0.47,y=0.93)
    return fig

# %%
# Create a mask to filter out values where the variance is less than
# 0.05% of the global mean variance
masks = [(d.stats['true_var'][:,:,d.tvars.index(v)].mean(1) < 
         d.stats['true_var'][:,:,d.tvars.index(v)].mean() * 0.0005) for v in vars]

# %% [markdown]
# #### Figures for paper

# %%
f = plot_4stats(d, 'r2', r'R$^2$', cmap='Spectral', mylims=[0, 1], rows=1, only_pos=True,
                masks=masks, extend='min')

# %%
f.savefig(f'{figdir}height-lat-r2.pdf', bbox_inches='tight')

# %%
f = plot_4stats(d, '', 'True standard deviation', vmult=0.5, cmap='Spectral_r', only_pos=True,
                func=lambda d, v: np.sqrt(d.stats['true_var'][:,:,d.tvars.index(v)].mean(1)),
                masks=masks, rows=1, letter_offset=2)

# %%
f.savefig(f'{figdir}height-lat-std.pdf', bbox_inches='tight')

# %%
f = plot_4stats(d, 'r2', r'R$^2$', cmap='Spectral', mylims=[0, 1], only_pos=True,
                masks=masks, extend='min')

# %%
f.savefig(f'{figdir}height-lat-r2_allvars.pdf', bbox_inches='tight')

# %%
f = plot_4stats(d, '', 'True standard deviation', vmult=0.5, cmap='Spectral_r', only_pos=True,
                func=lambda d, v: np.sqrt(d.stats['true_var'][:,:,d.tvars.index(v)].mean(1)),
                masks=masks, letter_offset=2)

# %%
f.savefig(f'{figdir}height-lat-std_allvars.pdf', bbox_inches='tight')

# %% [markdown]
# #### Additional statistics
#
# These are not in the final paper.

# %%
plot_4stats(d, '', 'Predicted / true standard deviation', vmult=0.3, cmap='Spectral', mylims=[0.2, 1],
            func=lambda d, v: (np.sqrt(d.stats['pred_var'][:,:,d.tvars.index(v)].mean(1)) /
                               np.sqrt(d.stats['true_var'][:,:,d.tvars.index(v)].mean(1))),
            rows=1, letter_offset=2, masks=masks
           )
# Out:
# /export/home/srasp/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plot_4stats(d, 'bias', 'Bias', vmult=0.01, cmap='bwr', rows=1)

# %%
plot_4stats(d, '', 'RMSE', vmult=0.2, cmap='magma_r', only_pos=True, rows=1,
            func=lambda d, v: np.sqrt(d.stats['mse'][:,:,d.tvars.index(v)].mean(1)),
            letter_offset=0)

# %%
plot_4stats('', 'True standard deviation', vmult=0.3, cmap='magma_r', only_pos=True,
            func=lambda d, v: np.sqrt(d.stats['true_var'][:,:,d.tvars.index(v)].mean(1)))

# %%
plot_4stats('', 'Predicted standard deviation', vmult=0.3, cmap='magma_r', only_pos=True,
            func=lambda d, v: np.sqrt(d.stats['pred_var'][:,:,d.tvars.index(v)].mean(1)))

# %%
plot_4stats(d, '', 'Predicted / true standard deviation', vmult=0.3, cmap='Spectral_r', mylims=[0, 1],
            func=lambda d, v: (np.sqrt(d.stats['mse'][:,:,d.tvars.index(v)].mean(1)) /
                               np.sqrt(d.stats['pred_var'][:,:,d.tvars.index(v)].mean(1)))
           )

# %%
plot_4stats(d, '', 'Predicted / true standard deviation', vmult=0.3, cmap='plasma', mylims=[0, 1],
            func=lambda d, v: (np.sqrt(d.stats['pred_var'][:,:,d.tvars.index(v)].mean(1)) /
                               np.sqrt(d.stats['true_var'][:,:,d.tvars.index(v)].mean(1)))
           )
# Out:
# /export/home/srasp/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plot_4stats(d, '', 'True standard deviation', vmult=0.3, cmap='inferno', only_pos=True, rows=1,
            func=lambda d, v: np.sqrt(d.stats['true_var'][:,:,d.tvars.index(v)].mean(1)))

# %%
plot_4stats(d, 'r2', r'R$^2$', cmap='RdYlGn', mylims=[0, 1], rows=1, only_pos=True,
            mask=lambda d, v: d.stats['r2'][:,:,d.tvars.index(v)].mean(1) < 0.05)

# %%
plot_4stats(d, '', 'Predicted / true standard deviation', vmult=0.3, cmap='RdYlGn', mylims=[0.2, 1],
            func=lambda d, v: (np.sqrt(d.stats['pred_var'][:,:,d.tvars.index(v)].mean(1)) /
                               np.sqrt(d.stats['true_var'][:,:,d.tvars.index(v)].mean(1))),
            rows=1, letter_offset=2
           )
# Out:
# /export/home/srasp/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### R2 by lev

# %%
fig, ax = plt.subplots(figsize=(4.5,4.5))
for i, v in enumerate(vars):
    ax.plot(d.stats['hor_r2'][i], lev, label=name[v], linewidth=2)
ax.invert_yaxis()
ax.set_ylabel('Pressure [hPa]'); ax.set_xlabel(r'R$^2$')
ax.set_xlim(0, 1)
ax.set_title(r'R$^2$ by height and variable')
despine(ax)
ax.legend(loc=(0.01,0.48));

# %%
fig.savefig(f'{figdir}mean-r2.pdf', bbox_inches='tight')

# %% [markdown]
# ## The end
